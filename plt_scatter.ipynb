# %% [markdown]
# <a href="https://colab.research.google.com/github/g00u00/colab/blob/main/plt_scatter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(7)
print(ys, sep=',',)
x = [x for x in range(len(ys))]
print(x)
print(type(x))

yz = [201.86508454, 200.92740682, 200.43188216, 201.48192017, 200.53357285, 199.5933559,  199.09593596]
x = [0, 5, 4, 3, 4, 5, 6]
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization")
plt.show()

fig = plt.figure(figsize=(17,5), dpi=100)
plt.scatter(x, ys,)
plt.show()
fig.savefig('./contentscatter.png')

os.getcwd()
os.listdir()
# Out:
# [200.60557744 197.88337544 200.96630831 199.27449102 200.05455679
#  198.46610044 199.86957401]
# [0, 1, 2, 3, 4, 5, 6]
# <class 'list'>
# ['.config', 'contentscatter.png', 'sample_data']
